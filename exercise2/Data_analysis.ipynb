# %% [markdown]
# # Scalability Study
# ## Fixed cores and variable matrix size

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
column_names = ['m', 'k', 'n', 'time', 'gflops']
MKL_close= pd.read_csv("./fxed_cores" + '/close_cores/mkl' + "_f" + '.csv', names=column_names, header=0)

MKL_close = MKL_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/lisadavinchie/Documents/Università/Introduction to HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> column_names = ['m', 'k', 'n', 'time', 'gflops']
# ----> <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> MKL_close= pd.read_csv("./fxed_cores" + '/close_cores/mkl' + "_f" + '.csv', names=column_names, header=0)
# ...

# %%
def plot_results(fixed_quantity, node_kind, precision, tpp):
    res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
    precision = "_" + precision
    
    linetype = ""
    column_names = ['m', 'k', 'n', 'time', 'gflops']
    
    
    
    MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)
    
    MKL_close = MKL_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')

    OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)
    
    OPENBLAS_close = OPENBLAS_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')

    BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)
    
    BLIS_close = BLIS_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')
    
    

    MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)
    
    MKL_spread = MKL_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')

    OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)
    
    OPENBLAS_spread = OPENBLAS_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')

    BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)
    
    BLIS_spread = BLIS_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')


    plt.plot(MKL_close['m'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
    plt.plot(OPENBLAS_close['m'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
    plt.plot(BLIS_close['m'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

    plt.plot(MKL_spread['m'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
    plt.plot(OPENBLAS_spread['m'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
    plt.plot(BLIS_spread['m'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

    plt.plot(BLIS_close['m'], [tpp] * BLIS_close['m'].size, label = "TPP", color = 'pink')
    plt.xlabel("Matrix dimension")
    plt.ylabel("Operations per seconds [Gflops/s]")
    plt.legend()
    plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
    plt.close()

# %%
fixed_quantity = "matrix"

node_kind = "THIN"

precision = "f"

res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
precision = "_" + precision

linetype = ""
column_names = ['m', 'k', 'n', 'time', 'gflops']



MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_close = MKL_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')

OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_close = OPENBLAS_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')

BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_close = BLIS_close.groupby("m")[['m', 'gflops', 'time']].transform('mean')



MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_spread = MKL_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')

OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_spread = OPENBLAS_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')

BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_spread = BLIS_spread.groupby("m")[['m', 'gflops', 'time']].transform('mean')


plt.plot(MKL_close['m'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
plt.plot(OPENBLAS_close['m'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
plt.plot(BLIS_close['m'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

plt.plot(MKL_spread['m'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
plt.plot(OPENBLAS_spread['m'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
plt.plot(BLIS_spread['m'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

plt.plot(BLIS_close['m'], [tpp] * BLIS_close['m'].size, label = "TPP", color = 'pink')
plt.xlabel("Matrix dimension")
plt.ylabel("Operations per seconds [Gflops/s]")
plt.legend()
plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lisadavinchie/Documents/Università/Introduction to HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb Cell 5 line 5
#      <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#X11sZmlsZQ%3D%3D?line=46'>47</a> plt.plot(OPENBLAS_spread['m'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
#      <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#X11sZmlsZQ%3D%3D?line=47'>48</a> plt.plot(BLIS_spread['m'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')
# ...

# %%
plot_results(fixed_quantity="cores", node_kind="THIN", precision="f", tpp=1997 * 0.5 * 2)
plot_results(fixed_quantity="cores", node_kind="THIN", precision="d", tpp=1997 * 0.5)

plot_results(fixed_quantity="cores", node_kind="EPYC", precision="f", tpp=2.60 * 16 * 64 * 2)
plot_results(fixed_quantity="cores", node_kind="EPYC", precision="d", tpp=2.60 * 16 * 64)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/lisadavinchie/Documents/Università/Introduction to HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> plot_results(fixed_quantity="cores", node_kind="THIN", precision="f", tpp=1997 * 0.5 * 2)
#       <a href='vscode-notebook-cell:/Users/lisadavinchie/Documents/Universita%CC%80/Introduction%20to%20HPC/Foundations_of_HPC_final_project/exercise2/Data_analysis.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> plot_results(fixed_quantity="cores", node_kind="THIN", precision="d", tpp=1997 * 0.5)
# ...

# %% [markdown]
# ## Fixed matrix size and variable cores

# %%
def plot_results(fixed_quantity, node_kind, precision, tpp):
    res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
    precision = "_" + precision
    
    linetype = ""

    column_names = ['cores', 'm', 'k', 'n', 'time', 'gflops']
    
    MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)
    
    
    
    MKL_close = MKL_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

    OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)
    
    OPENBLAS_close = OPENBLAS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

    BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)
    
    BLIS_close = BLIS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')
    
    

    MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)
    
    MKL_spread = MKL_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

    OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)
    
    OPENBLAS_spread = OPENBLAS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

    BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)
    
    BLIS_spread = BLIS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')


    plt.plot(MKL_close['cores'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
    plt.plot(OPENBLAS_close['cores'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
    plt.plot(BLIS_close['cores'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

    plt.plot(MKL_spread['cores'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
    plt.plot(OPENBLAS_spread['cores'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
    plt.plot(BLIS_spread['cores'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

    plt.plot(BLIS_close['cores'], [tpp] * BLIS_close['cores'], label = "TPP", color = 'pink')
    plt.xlabel("Number of cores used")
    plt.ylabel("Operations per seconds [Gflops/s]")
    plt.legend()
    plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
    plt.close()

# %%
plot_results(fixed_quantity="matrix", node_kind="THIN", precision="f", tpp=1997/24 * 2)
plot_results(fixed_quantity="matrix", node_kind="THIN", precision="d", tpp=1997/24)

plot_results(fixed_quantity="matrix", node_kind="EPYC", precision="f", tpp=2.60 * 16 * 2)
plot_results(fixed_quantity="matrix", node_kind="EPYC", precision="d", tpp=2.60 * 16)

# %%
fixed_quantity="matrix"
node_kind="THIN"
precision="f"
tpp=1997/24 * 2
    
res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
precision = "_" + precision

linetype = ""

column_names = ['cores', 'm', 'k', 'n', 'time', 'gflops']

MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)



MKL_close = MKL_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_close = OPENBLAS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_close = BLIS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')



MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_spread = MKL_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_spread = OPENBLAS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_spread = BLIS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')


plt.plot(MKL_close['cores'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
plt.plot(OPENBLAS_close['cores'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
plt.plot(BLIS_close['cores'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

plt.plot(MKL_spread['cores'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
plt.plot(OPENBLAS_spread['cores'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
plt.plot(BLIS_spread['cores'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

plt.plot(BLIS_close['cores'], [tpp] * BLIS_close['cores'], label = "TPP", color = 'pink')
plt.xlabel("Number of cores used")
plt.ylabel("Operations per seconds [Gflops/s]")
plt.legend()
plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
fixed_quantity="matrix"
node_kind="THIN"
precision="d"
tpp=1997/24
    
res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
precision = "_" + precision

linetype = ""

column_names = ['cores', 'm', 'k', 'n', 'time', 'gflops']

MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)



MKL_close = MKL_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_close = OPENBLAS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_close = BLIS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')



MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_spread = MKL_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_spread = OPENBLAS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_spread = BLIS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')


plt.plot(MKL_close['cores'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
plt.plot(OPENBLAS_close['cores'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
plt.plot(BLIS_close['cores'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

plt.plot(MKL_spread['cores'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
plt.plot(OPENBLAS_spread['cores'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
plt.plot(BLIS_spread['cores'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

plt.plot(BLIS_close['cores'], [tpp] * BLIS_close['cores'], label = "TPP", color = 'pink')
plt.xlabel("Number of cores used")
plt.ylabel("Operations per seconds [Gflops/s]")
plt.legend()
plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
fixed_quantity="matrix"
node_kind="EPYC"
precision="f"
tpp=1997/24 * 2
    
res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
precision = "_" + precision

linetype = ""

column_names = ['cores', 'm', 'k', 'n', 'time', 'gflops']

MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)



MKL_close = MKL_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_close = OPENBLAS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_close = BLIS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')



MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_spread = MKL_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_spread = OPENBLAS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_spread = BLIS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')


plt.plot(MKL_close['cores'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
plt.plot(OPENBLAS_close['cores'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
plt.plot(BLIS_close['cores'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

plt.plot(MKL_spread['cores'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
plt.plot(OPENBLAS_spread['cores'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
plt.plot(BLIS_spread['cores'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

plt.plot(BLIS_close['cores'], [tpp] * BLIS_close['cores'], label = "TPP", color = 'pink')
plt.xlabel("Number of cores used")
plt.ylabel("Operations per seconds [Gflops/s]")
plt.legend()
plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
fixed_quantity="matrix"
node_kind="EPYC"
precision="d"
tpp=1997/24 * 2
    
res_path = "./fixed_" + fixed_quantity + "/" + node_kind + "/"
precision = "_" + precision

linetype = ""

column_names = ['cores', 'm', 'k', 'n', 'time', 'gflops']

MKL_close= pd.read_csv(res_path + '/close_cores/mkl' + precision + '.csv', names=column_names, header=0)



MKL_close = MKL_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_close= pd.read_csv(res_path + '/close_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_close = OPENBLAS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_close = pd.read_csv(res_path + '/close_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_close = BLIS_close.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')



MKL_spread = pd.read_csv(res_path + '/spread_cores/mkl' + precision + '.csv', names=column_names, header=0)

MKL_spread = MKL_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

OPENBLAS_spread = pd.read_csv(res_path + '/spread_cores/openblas' + precision + '.csv', names=column_names, header=0)

OPENBLAS_spread = OPENBLAS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')

BLIS_spread = pd.read_csv(res_path + 'spread_cores/blis' + precision + '.csv', names=column_names, header=0)

BLIS_spread = BLIS_spread.groupby("cores")[['cores', 'gflops', 'time']].transform('mean')


plt.plot(MKL_close['cores'], MKL_close['gflops'], linetype, label = "MKL Close", color = 'deepskyblue')
plt.plot(OPENBLAS_close['cores'], OPENBLAS_close['gflops'], linetype, label = "OPENBLAS Close", color = 'dodgerblue')
plt.plot(BLIS_close['cores'], BLIS_close['gflops'], linetype, label = "BLIS Close", color = 'blue')

plt.plot(MKL_spread['cores'], MKL_spread['gflops'], linetype, label = "MKL Spread", color = 'springgreen')
plt.plot(OPENBLAS_spread['cores'], OPENBLAS_spread['gflops'], linetype, label = "OPENBLAS Spread", color = 'limegreen')
plt.plot(BLIS_spread['cores'], BLIS_spread['gflops'], linetype, label = "BLIS Spread", color = 'forestgreen')

plt.plot(BLIS_close['cores'], [tpp] * BLIS_close['cores'], label = "TPP", color = 'pink')
plt.xlabel("Number of cores used")
plt.ylabel("Operations per seconds [Gflops/s]")
plt.legend()
plt.savefig("fixed_" + fixed_quantity + "_" + node_kind + precision + ".png")
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>
